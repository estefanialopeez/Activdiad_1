# %% [markdown]
# <a href="https://colab.research.google.com/github/estefanialopeez/Activdiad_1/blob/main/Entregable1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#cargar archivo csv desde el equipo
from google.colab import files
files.upload()

# %%
df=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx')

#filtros de encabezado y datos finales del data frame generado a partir de excel
df.tail(3)
filtro9= df.head(3)
filtro9
# Out:
#   CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR                NOMBRE_CLIENTE  \
# 0  F37034 2022-01-05  LETICIA RAMIREZ HERNANDEZ            PÚBLICO EN GENERAL
# 1  F37036 2022-01-05  LETICIA RAMIREZ HERNANDEZ  JUAN ANTONIO RESENDIZ UGALDE
# 2  F37041 2022-01-05   DIEGO ARMANDO LEON DURAN     ANA BARBARA CRUZ PALACIOS
#
#    CANT   CVE_ART                                    DESCR  PRECIO_UNITARIO  \
# 0     1  TUE00244  TUB COBRE 5/16"ØX165MM CIRCULA1.5KW127V           434.48
# 1     1  TUA00028  TUA U" 5/16 ØX250MM 1200W 120V TAP1"NPT          1264.05
# 2     7    TP0007     TERMOPAR J 3/16 Ø X 1' 1/2 EXT. 7 MT           551.61
#
#    COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 0           52.80                     52.80            434.48
# 1          327.18                    327.18           1264.05
# 2          177.68                    177.68           3861.29
#
#    COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  MARGEN_TOTAL_CALCULADO
# ...

# %%
filtro9.to_csv('Filtro9.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro9.csv')

# %%
#fitro por objerto
filtro1=df[df['NOMBRE_VENDEDOR']=='DIEGO ARMANDO LEON DURAN']
filtro1
# Out:
#      CVE_DOC  FECHA_DOC           NOMBRE_VENDEDOR  \
# 2     F37041 2022-01-05  DIEGO ARMANDO LEON DURAN
# 3     F37042 2022-01-05  DIEGO ARMANDO LEON DURAN
# 6     F37044 2022-01-05  DIEGO ARMANDO LEON DURAN
# 8     F37048 2022-01-05  DIEGO ARMANDO LEON DURAN
# 9     F37049 2022-01-05  DIEGO ARMANDO LEON DURAN
# ...      ...        ...                       ...
# 519   F38005 2022-04-27  DIEGO ARMANDO LEON DURAN
# 580   F38141 2022-05-12  DIEGO ARMANDO LEON DURAN
# 731   F38459 2022-06-24  DIEGO ARMANDO LEON DURAN
# 851   F38665 2022-07-26  DIEGO ARMANDO LEON DURAN
# 1296  F39592 2022-11-16  DIEGO ARMANDO LEON DURAN
#
#                            NOMBRE_CLIENTE  CANT   CVE_ART  \
# 2               ANA BARBARA CRUZ PALACIOS     7    TP0007
# 3                    OMAR RODRIGUEZ GOMEZ     1    TP0001
# 6     AIRBUS HELICOPTERS MEXICO QUERETARO     1   RP00165
# 8                      FIDEICOMISO F/1596     1  TUE00207
# 9                      FIDEICOMISO F/1596     1  TUE00207
# ...

# %%
filtro1.to_csv('Filtro1.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro1.csv')

# %%
#filtro por filas
#filtro2=df.iloc[40:80, : ]          #filas consecutivas
filtro2= df.iloc[ [50,70,100],:]     #filas no consecutivas
filtro2
# Out:
#     CVE_DOC  FECHA_DOC            NOMBRE_VENDEDOR  \
# 50   F37125 2022-01-17  LETICIA RAMIREZ HERNANDEZ
# 70   F37156 2022-01-20   DIEGO ARMANDO LEON DURAN
# 100  F37223 2022-01-28  LETICIA RAMIREZ HERNANDEZ
#
#                                        NOMBRE_CLIENTE  CANT   CVE_ART  \
# 50                             MANUFACTURAS METALICAS     5  TUS00003
# 70                         DIANA LAURA ZAVALA SALAZAR     1   BP00244
# 100  COMPONENTES ELECTRICOS Y DISPOSITIVOS ESPECIALES     1    TP0025
#
#                                         DESCR  PRECIO_UNITARIO  \
# 50   TUB. INOX. 5/16 Øx615mm. 2000W 440V "U""           531.00
# 70      BAN P INOX 28MMX128MM 125W 230V T/TOR           255.01
# 100    TERMOPAR K 3/16Ø  X 1'  1/2 EXT. 2 MT"           175.00
#
#      COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# 50            85.29                     85.29           2655.00
# 70           291.72                    291.72            255.01
# ...

# %%
filtro2.to_csv('Filtro2.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro2.csv')

# %%
#Filtro por columnas
#filtro3 = df.iloc[ , 1:3]          #Columnas consecutivas
filtro3 = df.iloc[ : ,[2,7,9,11]]    #Columnas no consecutivas
filtro3
# Out:
#                 NOMBRE_VENDEDOR  PRECIO_UNITARIO  COSTO_UNITARIO_CALCULADO  \
# 0     LETICIA RAMIREZ HERNANDEZ           434.48                     52.80
# 1     LETICIA RAMIREZ HERNANDEZ          1264.05                    327.18
# 2      DIEGO ARMANDO LEON DURAN           551.61                    177.68
# 3      DIEGO ARMANDO LEON DURAN           140.00                     38.96
# 4     LETICIA RAMIREZ HERNANDEZ           172.41                    101.71
# ...                         ...              ...                       ...
# 1421  LETICIA RAMIREZ HERNANDEZ           712.00                    102.31
# 1422  LETICIA RAMIREZ HERNANDEZ           718.60                    104.69
# 1423  LETICIA RAMIREZ HERNANDEZ          2182.35                    596.55
# 1424  LETICIA RAMIREZ HERNANDEZ          5909.84                   1884.35
# 1425         AARON NUÑO CORDOVA          1406.00                     80.66
#
#       COSTO_TOTAL_CALCULADO
# 0                     52.80
# ...

# %%
filtro3.to_csv('Filtro3.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro3.csv')

# %%
df1= df=pd.read_excel('Detalle precios y productos fabricados 2022.xlsx', index_col='NOMBRE_VENDEDOR')

#filtro de columnas contra filas
filtro4= df.loc[['DIEGO ARMANDO LEON DURAN','LETICIA RAMIREZ HERNANDEZ'], ['COSTO_TOTAL_CALCULADO']]
filtro4
# Out:
#                            COSTO_TOTAL_CALCULADO
# NOMBRE_VENDEDOR
# DIEGO ARMANDO LEON DURAN                 1243.73
# DIEGO ARMANDO LEON DURAN                   38.96
# DIEGO ARMANDO LEON DURAN                 5323.76
# DIEGO ARMANDO LEON DURAN                  517.89
# DIEGO ARMANDO LEON DURAN                  517.89
# ...                                          ...
# LETICIA RAMIREZ HERNANDEZ                 369.62
# LETICIA RAMIREZ HERNANDEZ                 613.88
# LETICIA RAMIREZ HERNANDEZ                 628.12
# LETICIA RAMIREZ HERNANDEZ                1789.64
# LETICIA RAMIREZ HERNANDEZ                1884.35
#
# [1015 rows x 1 columns]

# %%
filtro5= df[df['COSTO_TOTAL_CALCULADO']> 100000]
filtro5
# Out:
#                 CVE_DOC  FECHA_DOC      NOMBRE_CLIENTE  CANT  CVE_ART  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA   F38352 2022-06-10  FLEX-N-GATE MEXICO     1  RP00203
#
#                                             DESCR  PRECIO_UNITARIO  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA   REPARACION HORNO 15KW 440V TOTAL         32582.18
#
#                  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA              0.0                 199335.56          32582.18
#
#                  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA               199335.56                 -166753.38
#
#                  MARGEN_TOTAL_CALCULADO
# NOMBRE_VENDEDOR
# ALFREDO CANELA               -166753.38

# %%
filtro5.to_csv('Filtro5.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro5.csv')

# %%
#filtro Y
filtro6= df[(df['COSTO_TOTAL_CALCULADO']<10000) & (df['DESCR']== 'BOBINA CAL.8 DSD C/TERMINALES EN INOX')]
filtro6
# Out:
#                 CVE_DOC  FECHA_DOC         NOMBRE_CLIENTE  CANT    CVE_ART  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA   F37078 2022-01-07  CLAVOS NACIONALES C.N    30  BOBINA001
# ALFREDO CANELA   F37086 2022-01-10  CLAVOS NACIONALES C.N    30  BOBINA001
#
#                                                  DESCR  PRECIO_UNITARIO  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA   BOBINA CAL.8 DSD C/TERMINALES EN INOX          1299.32
# ALFREDO CANELA   BOBINA CAL.8 DSD C/TERMINALES EN INOX          1299.32
#
#                  COSTO_UNITARIO  COSTO_UNITARIO_CALCULADO  SUBTOTAL_PARTIDA  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA           305.44                    305.44           38979.6
# ALFREDO CANELA           305.44                    305.44           38979.6
#
#                  COSTO_TOTAL_CALCULADO  MARGEN_UNITARIO_CALCULADO  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA                 9163.18                     993.88
# ALFREDO CANELA                 9163.18                     993.88
#
# ...

# %%
filtro6.to_csv('Filtro6.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro6.csv')

# %%
#filtro or
filtro7= df[(df['COSTO_TOTAL_CALCULADO']<10000) | (df['DESCR']== 'BOBINA CAL.8 DSD C/TERMINALES EN INOX')]
filtro7
# Out:
#                           CVE_DOC  FECHA_DOC                NOMBRE_CLIENTE  \
# NOMBRE_VENDEDOR
# LETICIA RAMIREZ HERNANDEZ  F37034 2022-01-05            PÚBLICO EN GENERAL
# LETICIA RAMIREZ HERNANDEZ  F37036 2022-01-05  JUAN ANTONIO RESENDIZ UGALDE
# DIEGO ARMANDO LEON DURAN   F37041 2022-01-05     ANA BARBARA CRUZ PALACIOS
# DIEGO ARMANDO LEON DURAN   F37042 2022-01-05          OMAR RODRIGUEZ GOMEZ
# LETICIA RAMIREZ HERNANDEZ  F37043 2022-01-05            PÚBLICO EN GENERAL
# ...                           ...        ...                           ...
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39834 2022-12-23     LUIS ENRIQUE PATIÑO PEREZ
# LETICIA RAMIREZ HERNANDEZ  F39835 2022-12-23          SEVEN DAYS ALL SPORT
# LETICIA RAMIREZ HERNANDEZ  F39837 2022-12-23           REVUELTA MONTECARLO
# AARON NUÑO CORDOVA         F39838 2022-12-23                CPEG SOLUTIONS
#
#                            CANT       CVE_ART  \
# ...

# %%
filtro7.to_csv('Filtro7.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro7.csv')

# %%
#filtro not
filtro8 = df[~(df['COSTO_TOTAL_CALCULADO']<10000) | (df['DESCR']== 'BOBINA CAL.8 DSD C/TERMINALES EN INOX')]
filtro8
# Out:
#                           CVE_DOC  FECHA_DOC  \
# NOMBRE_VENDEDOR
# ALFREDO CANELA             F37078 2022-01-07
# ALFREDO CANELA             F37086 2022-01-10
# ALFREDO CANELA             F37493 2022-02-28
# ALFREDO CANELA             F37758 2022-03-29
# ALFREDO CANELA             F37777 2022-03-31
# ALFREDO CANELA             F37977 2022-04-25
# ALFREDO CANELA             F38047 2022-04-29
# LETICIA RAMIREZ HERNANDEZ  F38221 2022-05-24
# ALFREDO CANELA             F38344 2022-06-09
# ALFREDO CANELA             F38352 2022-06-10
# ALFREDO CANELA             F38638 2022-07-21
# ALFREDO CANELA             F38797 2022-08-11
# ALFREDO CANELA             F39121 2022-09-22
# ALFREDO CANELA             F39139 2022-09-23
# ALFREDO CANELA             F39139 2022-09-23
# LETICIA RAMIREZ HERNANDEZ  F39183 2022-09-29
# LETICIA RAMIREZ HERNANDEZ  F39191 2022-09-30
# ALFREDO CANELA             F39342 2022-10-19
# ALFREDO CANELA             F39633 2022-11-25
# ...

# %%
filtro8.to_csv('Filtro8.csv')
#convertir archivo filtrado

from google.colab import files
files.download('Filtro8.csv')
